# %%
import os
import pandas as pd
from google import genai
from google.genai import types
from PIL import Image
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sentence_transformers import SentenceTransformer, util
from scipy.stats import spearmanr

# %% [markdown]
# Description function

# %%
client = genai.Client(api_key="ENTER API KEY HERE") # Replace with your actual API key

# We use Flash-Lite for maximum value/speed
model_id = "gemini-2.5-flash-lite" 

def generate_description(image_path, prompt, model_id):
    sketch = Image.open(image_path)

    response = client.models.generate_content(
        model=model_id,
        contents=[prompt, sketch]
    )
    
    return response.text

def get_folder(category, condition):
    
    # get folder 
    if condition == "_control" or condition == "":
        data_folder = "../../drawings/"
    elif condition == "_photos":
        data_folder = "../../photos/"
    else:
        raise ValueError(f"Unsupported condition: {condition}")
      
    print(f"Selected folder: {data_folder}")  
    return data_folder


# 3. Load Images and Captions
def get_job_list(category, condition):

    # get folder
    print("Get images and captions")
    folder = get_folder(category, condition)

    # Filter for category files (e.g., 'kit' in filename)
    if condition == "_control":
        exts = (".png")
        files = [f for f in os.listdir(folder) if f.lower().endswith(exts) and category[0:3] in f
                 and not "'" in f and not "gen" in f and "copy" in f] 
    elif condition == "":
        exts = (".png")
        files = [f for f in os.listdir(folder) if f.lower().endswith(exts) and category[0:3] in f 
                 and not "'" in f and not "gen" in f and not "copy" in f] 
    elif condition == "_photos":
        exts = (".png")
        files = [f for f in os.listdir(folder) if f.lower().endswith(exts) and category[0:3] in f] 

    # Load captions
    captions = pd.DataFrame() # empty dataframe for photos condition  
    if condition == "_control" or condition == "":
        caption_file = os.path.join(folder, f"{category}{condition}_objects.csv")
        captions = pd.read_csv(caption_file, sep=",", header=0)
        captions = captions.iloc[:, 1:] # remove first column

    return sorted(files), captions, folder

def get_description(cate, condition, max_retries=5, retry_delay=10, image_repetitions=1, stimuli_subset=None):    
    
    print(f"Getting descriptions for {condition} on {cate}")
    
    # get files and folder
    files, captions, data_folder = get_job_list(cate, condition)

    if stimuli_subset is not None:
        files = files[int(stimuli_subset[0]):int(stimuli_subset[1])]

    if image_repetitions > 1:   
        files = files*image_repetitions
        files.sort()   

        if captions.shape[0] > 5:
            captions = captions.loc[captions.index.repeat(image_repetitions)].reset_index(drop=True)
           
    print(len(files))
    print(captions.shape)

    csv_log_file = os.path.join(data_folder, f"gem_2-5_descriptions_{cate}{condition}.csv")

    print(f"🚀 Starting batch. Data will be saved to: {csv_log_file}")

    # 1. INITIALIZE FILE: Use 'w' mode to create/clear the file and write the header
    with open(csv_log_file, "w", encoding="utf-8") as f_init:
        f_init.write("filename,original_caption,detailed_description\n")

    # 2. BATCH LOOP: open in 'a' mode for safe appending during the loop
    with open(csv_log_file, "a", encoding="utf-8") as f_log:
        for i, filename in enumerate(files):
            input_path = os.path.join(data_folder, filename)
            
            if condition == "_control" or condition == "":
                objects = captions.iloc[i].astype(str)
                objects = objects[objects != 'nan']
                current_desc = ", ".join(objects)

                prompt = f"""
                Analyze this line drawing of a {cate} including {current_desc}. 
                Provide a detailed description of approximately 200 words in natural language.
                Include all visible objects, furniture, and specific layout details.
                Focus on the content and layout of the drawing, not the artistic style or quality.
                Format as a single clean paragraph of text.
                """
            elif condition == "_photos":
                current_desc = "N/A for photos"
                prompt = f"""
                Analyze this photo of a {cate}. 
                Provide a detailed description of approximately 200 words in natural language.
                Include all visible objects, furniture, and specific layout details.
                Focus on the content and layout of the photo, not the photographic style or quality.
                Format as a single clean paragraph of text.
                """

            print(f"[{i+1}/{len(files)}] Processing: {filename}...", end=" ")

            success = False
            for attempt in range(max_retries):
                try:
                    detailed_brief = generate_description(input_path, prompt, model_id)
                    
                    # Sanitize text for CSV: remove newlines and escape quotes
                    clean_brief = detailed_brief.replace('\n', ' ').replace('"', '""')
                    clean_caption = current_desc.replace('"', '""')
                    
                    # Write formatted CSV row
                    f_log.write(f'"{filename}","{clean_caption}","{clean_brief}"\n')
                    f_log.flush() # Ensure it writes to disk immediately
                    
                    print("✅ Done.")
                    success = True
                    break 
                    
                except Exception as e:
                    # Exponential backoff: 10s, 40s, 90s...
                    wait_time = retry_delay * ((attempt + 1) ** 2)
                    print(f"⚠️ Attempt {attempt+1} failed: {e}. Retrying in {wait_time}s...")
                    time.sleep(wait_time)

            if not success:
                print(f"❌ Failed after {max_retries} attempts.")
                f_log.write(f'"{filename}","{current_desc}","ERROR: Generation Failed"\n')
                f_log.flush()

            time.sleep(2) # Tier 1 polite delay

# %% [markdown]
# Get descriptions from images and prompts

# %%
# 1. Setup paths and model
cates = ["kitchen", "bathroom"]
conditions = ["", "_control", "_photos"]

for cate in cates:
    for condition in conditions:  
        get_description(cate, condition,
                        max_retries=5, retry_delay=10,
                        image_repetitions=3, stimuli_subset=None
                        )
# Out:
# Getting descriptions for  on kitchen
# Get images and captions
# Selected folder: ../../drawings/
# 90
# (90, 16)
# 🚀 Starting batch. Data will be saved to: ../../drawings/gem_2-5_descriptions_kitchen.csv
# [1/90] Processing: 101_kit.png... ✅ Done.
# [2/90] Processing: 101_kit.png... ✅ Done.
# [3/90] Processing: 101_kit.png... ✅ Done.
# [4/90] Processing: 102_kit.png... ✅ Done.
# [5/90] Processing: 102_kit.png... ✅ Done.
# [6/90] Processing: 102_kit.png... ✅ Done.
# [7/90] Processing: 103_kit.png... ✅ Done.
# [8/90] Processing: 103_kit.png... ✅ Done.
# [9/90] Processing: 103_kit.png... ✅ Done.
# [10/90] Processing: 104_kit.png... ✅ Done.
# [11/90] Processing: 104_kit.png... ✅ Done.
# [12/90] Processing: 104_kit.png... ✅ Done.
# [13/90] Processing: 105_kit.png... ✅ Done.
# [14/90] Processing: 105_kit.png... ✅ Done.
# [15/90] Processing: 105_kit.png... ✅ Done.
# [16/90] Processing: 106_kit.png... ✅ Done.
# [17/90] Processing: 106_kit.png... ✅ Done.
# [18/90] Processing: 106_kit.png... ✅ Done.
# [19/90] Processing: 107_kit.png... ✅ Done.
# [20/90] Processing: 107_kit.png... ✅ Done.
# [21/90] Processing: 107_kit.png... ✅ Done.
# [22/90] Processing: 108_kit.png... ✅ Done.
# [23/90] Processing: 108_kit.png... ✅ Done.
# [24/90] Processing: 108_kit.png... ✅ Done.
# [25/90] Processing: 109_kit.png... ✅ Done.
# [26/90] Processing: 109_kit.png... ✅ Done.
# [27/90] Processing: 109_kit.png... ✅ Done.
# [28/90] Processing: 110_kit.png... ✅ Done.
# [29/90] Processing: 110_kit.png... ✅ Done.
# [30/90] Processing: 110_kit.png... ✅ Done.
# [31/90] Processing: 111_kit.png... ✅ Done.
# [32/90] Processing: 111_kit.png... ✅ Done.
# [33/90] Processing: 111_kit.png... ✅ Done.
# [34/90] Processing: 112_kit.png... ✅ Done.
# [35/90] Processing: 112_kit.png... ✅ Done.
# [36/90] Processing: 112_kit.png... ✅ Done.
# [37/90] Processing: 113_kit.png... ✅ Done.
# [38/90] Processing: 113_kit.png... ✅ Done.
# [39/90] Processing: 113_kit.png... ✅ Done.
# [40/90] Processing: 114_kit.png... ✅ Done.
# [41/90] Processing: 114_kit.png... ✅ Done.
# [42/90] Processing: 114_kit.png... ✅ Done.
# [43/90] Processing: 115_kit.png... ✅ Done.
# [44/90] Processing: 115_kit.png... ✅ Done.
# [45/90] Processing: 115_kit.png... ✅ Done.
# [46/90] Processing: 116_kit.png... ✅ Done.
# [47/90] Processing: 116_kit.png... ✅ Done.
# [48/90] Processing: 116_kit.png... ✅ Done.
# [49/90] Processing: 117_kit.png... ✅ Done.
# [50/90] Processing: 117_kit.png... ✅ Done.
# [51/90] Processing: 117_kit.png... ✅ Done.
# [52/90] Processing: 119_kit.png... ✅ Done.
# [53/90] Processing: 119_kit.png... ✅ Done.
# [54/90] Processing: 119_kit.png... ✅ Done.
# [55/90] Processing: 120_kit.png... ✅ Done.
# [56/90] Processing: 120_kit.png... ✅ Done.
# [57/90] Processing: 120_kit.png... ✅ Done.
# [58/90] Processing: 121_kit.png... ✅ Done.
# [59/90] Processing: 121_kit.png... ✅ Done.
# [60/90] Processing: 121_kit.png... ✅ Done.
# [61/90] Processing: 122_kit.png... ✅ Done.
# [62/90] Processing: 122_kit.png... ✅ Done.
# [63/90] Processing: 122_kit.png... ✅ Done.
# [64/90] Processing: 123_kit.png... ✅ Done.
# [65/90] Processing: 123_kit.png... ✅ Done.
# [66/90] Processing: 123_kit.png... ✅ Done.
# [67/90] Processing: 124_kit.png... ✅ Done.
# [68/90] Processing: 124_kit.png... ✅ Done.
# [69/90] Processing: 124_kit.png... ✅ Done.
# [70/90] Processing: 126_kit.png... ✅ Done.
# [71/90] Processing: 126_kit.png... ✅ Done.
# [72/90] Processing: 126_kit.png... ✅ Done.
# [73/90] Processing: 127_kit.png... ✅ Done.
# [74/90] Processing: 127_kit.png... ✅ Done.
# [75/90] Processing: 127_kit.png... ✅ Done.
# [76/90] Processing: 128_kit.png... ✅ Done.
# [77/90] Processing: 128_kit.png... ✅ Done.
# [78/90] Processing: 128_kit.png... ✅ Done.
# [79/90] Processing: 129_kit.png... ✅ Done.
# [80/90] Processing: 129_kit.png... ✅ Done.
# [81/90] Processing: 129_kit.png... ✅ Done.
# [82/90] Processing: 130_kit.png... ✅ Done.
# [83/90] Processing: 130_kit.png... ✅ Done.
# [84/90] Processing: 130_kit.png... ✅ Done.
# [85/90] Processing: 132_kit.png... ✅ Done.
# [86/90] Processing: 132_kit.png... ✅ Done.
# [87/90] Processing: 132_kit.png... ✅ Done.
# [88/90] Processing: 133_kit.png... ✅ Done.
# [89/90] Processing: 133_kit.png... ✅ Done.
# [90/90] Processing: 133_kit.png... ✅ Done.
# Getting descriptions for _control on kitchen
# Get images and captions
# Selected folder: ../../drawings/
# 90
# (90, 25)
# 🚀 Starting batch. Data will be saved to: ../../drawings/gem_2-5_descriptions_kitchen_control.csv
# [1/90] Processing: 101_kit_copy.png... ✅ Done.
# [2/90] Processing: 101_kit_copy.png... ✅ Done.
# [3/90] Processing: 101_kit_copy.png... ✅ Done.
# [4/90] Processing: 102_kit_copy.png... ✅ Done.
# [5/90] Processing: 102_kit_copy.png... ✅ Done.
# [6/90] Processing: 102_kit_copy.png... ✅ Done.
# [7/90] Processing: 103_kit_copy.png... ✅ Done.
# [8/90] Processing: 103_kit_copy.png... ✅ Done.
# [9/90] Processing: 103_kit_copy.png... ✅ Done.
# [10/90] Processing: 104_kit_copy.png... ✅ Done.
# [11/90] Processing: 104_kit_copy.png... ✅ Done.
# [12/90] Processing: 104_kit_copy.png... ✅ Done.
# [13/90] Processing: 105_kit_copy.png... ✅ Done.
# [14/90] Processing: 105_kit_copy.png... ✅ Done.
# [15/90] Processing: 105_kit_copy.png... ✅ Done.
# [16/90] Processing: 106_kit_copy.png... ✅ Done.
# [17/90] Processing: 106_kit_copy.png... ✅ Done.
# [18/90] Processing: 106_kit_copy.png... ✅ Done.
# [19/90] Processing: 107_kit_copy.png... ✅ Done.
# [20/90] Processing: 107_kit_copy.png... ✅ Done.
# [21/90] Processing: 107_kit_copy.png... ✅ Done.
# [22/90] Processing: 108_kit_copy.png... ✅ Done.
# [23/90] Processing: 108_kit_copy.png... ✅ Done.
# [24/90] Processing: 108_kit_copy.png... ✅ Done.
# [25/90] Processing: 109_kit_copy.png... ✅ Done.
# [26/90] Processing: 109_kit_copy.png... ✅ Done.
# [27/90] Processing: 109_kit_copy.png... ✅ Done.
# [28/90] Processing: 110_kit_copy.png... ✅ Done.
# [29/90] Processing: 110_kit_copy.png... ✅ Done.
# [30/90] Processing: 110_kit_copy.png... ✅ Done.
# [31/90] Processing: 111_kit_copy.png... ✅ Done.
# [32/90] Processing: 111_kit_copy.png... ✅ Done.
# [33/90] Processing: 111_kit_copy.png... ✅ Done.
# [34/90] Processing: 112_kit_copy.png... ✅ Done.
# [35/90] Processing: 112_kit_copy.png... ✅ Done.
# [36/90] Processing: 112_kit_copy.png... ✅ Done.
# [37/90] Processing: 113_kit_copy.png... ✅ Done.
# [38/90] Processing: 113_kit_copy.png... ✅ Done.
# [39/90] Processing: 113_kit_copy.png... ✅ Done.
# [40/90] Processing: 114_kit_copy.png... ✅ Done.
# [41/90] Processing: 114_kit_copy.png... ✅ Done.
# [42/90] Processing: 114_kit_copy.png... ✅ Done.
# [43/90] Processing: 115_kit_copy.png... ✅ Done.
# [44/90] Processing: 115_kit_copy.png... ✅ Done.
# [45/90] Processing: 115_kit_copy.png... ✅ Done.
# [46/90] Processing: 116_kit_copy.png... ✅ Done.
# [47/90] Processing: 116_kit_copy.png... ✅ Done.
# [48/90] Processing: 116_kit_copy.png... ✅ Done.
# [49/90] Processing: 117_kit_copy.png... ✅ Done.
# [50/90] Processing: 117_kit_copy.png... ✅ Done.
# [51/90] Processing: 117_kit_copy.png... ✅ Done.
# [52/90] Processing: 119_kit_copy.png... ✅ Done.
# [53/90] Processing: 119_kit_copy.png... ✅ Done.
# [54/90] Processing: 119_kit_copy.png... ✅ Done.
# [55/90] Processing: 120_kit_copy.png... ✅ Done.
# [56/90] Processing: 120_kit_copy.png... ✅ Done.
# [57/90] Processing: 120_kit_copy.png... ✅ Done.
# [58/90] Processing: 121_kit_copy.png... ✅ Done.
# [59/90] Processing: 121_kit_copy.png... ✅ Done.
# [60/90] Processing: 121_kit_copy.png... ✅ Done.
# [61/90] Processing: 122_kit_copy.png... ✅ Done.
# [62/90] Processing: 122_kit_copy.png... ✅ Done.
# [63/90] Processing: 122_kit_copy.png... ✅ Done.
# [64/90] Processing: 123_kit_copy.png... ✅ Done.
# [65/90] Processing: 123_kit_copy.png... ✅ Done.
# [66/90] Processing: 123_kit_copy.png... ✅ Done.
# [67/90] Processing: 124_kit_copy.png... ✅ Done.
# [68/90] Processing: 124_kit_copy.png... ✅ Done.
# [69/90] Processing: 124_kit_copy.png... ✅ Done.
# [70/90] Processing: 126_kit_copy.png... ✅ Done.
# [71/90] Processing: 126_kit_copy.png... ✅ Done.
# [72/90] Processing: 126_kit_copy.png... ✅ Done.
# [73/90] Processing: 127_kit_copy.png... ✅ Done.
# [74/90] Processing: 127_kit_copy.png... ✅ Done.
# [75/90] Processing: 127_kit_copy.png... ✅ Done.
# [76/90] Processing: 128_kit_copy.png... ✅ Done.
# [77/90] Processing: 128_kit_copy.png... ✅ Done.
# [78/90] Processing: 128_kit_copy.png... ✅ Done.
# [79/90] Processing: 129_kit_copy.png... ✅ Done.
# [80/90] Processing: 129_kit_copy.png... ✅ Done.
# [81/90] Processing: 129_kit_copy.png... ✅ Done.
# [82/90] Processing: 130_kit_copy.png... ✅ Done.
# [83/90] Processing: 130_kit_copy.png... ✅ Done.
# [84/90] Processing: 130_kit_copy.png... ✅ Done.
# [85/90] Processing: 132_kit_copy.png... ✅ Done.
# [86/90] Processing: 132_kit_copy.png... ✅ Done.
# [87/90] Processing: 132_kit_copy.png... ✅ Done.
# [88/90] Processing: 133_kit_copy.png... ✅ Done.
# [89/90] Processing: 133_kit_copy.png... ✅ Done.
# [90/90] Processing: 133_kit_copy.png... ✅ Done.
# Getting descriptions for _photos on kitchen
# Get images and captions
# Selected folder: ../../photos/
# 99
# (0, 0)
# 🚀 Starting batch. Data will be saved to: ../../photos/gem_2-5_descriptions_kitchen_photos.csv
# [1/99] Processing: 101_kit.png... ✅ Done.
# [2/99] Processing: 101_kit.png... ✅ Done.
# [3/99] Processing: 101_kit.png... ✅ Done.
# [4/99] Processing: 102_kit.png... ✅ Done.
# [5/99] Processing: 102_kit.png... ✅ Done.
# [6/99] Processing: 102_kit.png... ✅ Done.
# [7/99] Processing: 103_kit.png... ✅ Done.
# [8/99] Processing: 103_kit.png... ✅ Done.
# [9/99] Processing: 103_kit.png... ✅ Done.
# [10/99] Processing: 104_kit.png... ✅ Done.
# [11/99] Processing: 104_kit.png... ✅ Done.
# [12/99] Processing: 104_kit.png... ✅ Done.
# [13/99] Processing: 105_kit.png... ✅ Done.
# [14/99] Processing: 105_kit.png... ✅ Done.
# [15/99] Processing: 105_kit.png... ✅ Done.
# [16/99] Processing: 106_kit.png... ✅ Done.
# [17/99] Processing: 106_kit.png... ✅ Done.
# [18/99] Processing: 106_kit.png... ✅ Done.
# [19/99] Processing: 107_kit.png... ✅ Done.
# [20/99] Processing: 107_kit.png... ✅ Done.
# [21/99] Processing: 107_kit.png... ✅ Done.
# [22/99] Processing: 108_kit.png... ✅ Done.
# [23/99] Processing: 108_kit.png... ✅ Done.
# [24/99] Processing: 108_kit.png... ✅ Done.
# [25/99] Processing: 109_kit.png... ✅ Done.
# [26/99] Processing: 109_kit.png... ✅ Done.
# [27/99] Processing: 109_kit.png... ✅ Done.
# [28/99] Processing: 110_kit.png... ✅ Done.
# [29/99] Processing: 110_kit.png... ✅ Done.
# [30/99] Processing: 110_kit.png... ✅ Done.
# [31/99] Processing: 111_kit1.png... ✅ Done.
# [32/99] Processing: 111_kit1.png... ✅ Done.
# [33/99] Processing: 111_kit1.png... ✅ Done.
# [34/99] Processing: 111_kit2.png... ✅ Done.
# [35/99] Processing: 111_kit2.png... ✅ Done.
# [36/99] Processing: 111_kit2.png... ✅ Done.
# [37/99] Processing: 112_kit.png... ✅ Done.
# [38/99] Processing: 112_kit.png... ✅ Done.
# [39/99] Processing: 112_kit.png... ✅ Done.
# [40/99] Processing: 113_kit.png... ✅ Done.
# [41/99] Processing: 113_kit.png... ✅ Done.
# [42/99] Processing: 113_kit.png... ✅ Done.
# [43/99] Processing: 114_kit.png... ✅ Done.
# [44/99] Processing: 114_kit.png... ✅ Done.
# [45/99] Processing: 114_kit.png... ✅ Done.
# [46/99] Processing: 115_kit.png... ✅ Done.
# [47/99] Processing: 115_kit.png... ✅ Done.
# [48/99] Processing: 115_kit.png... ✅ Done.
# [49/99] Processing: 116_kit.png... ✅ Done.
# [50/99] Processing: 116_kit.png... ✅ Done.
# [51/99] Processing: 116_kit.png... ✅ Done.
# [52/99] Processing: 117_kit.png... ✅ Done.
# [53/99] Processing: 117_kit.png... ✅ Done.
# [54/99] Processing: 117_kit.png... ✅ Done.
# [55/99] Processing: 119_kit.png... ✅ Done.
# [56/99] Processing: 119_kit.png... ✅ Done.
# [57/99] Processing: 119_kit.png... ✅ Done.
# [58/99] Processing: 120_kit.png... ✅ Done.
# [59/99] Processing: 120_kit.png... ✅ Done.
# [60/99] Processing: 120_kit.png... ✅ Done.
# [61/99] Processing: 121_kit.png... ✅ Done.
# [62/99] Processing: 121_kit.png... ✅ Done.
# [63/99] Processing: 121_kit.png... ✅ Done.
# [64/99] Processing: 122_kit.png... ✅ Done.
# [65/99] Processing: 122_kit.png... ✅ Done.
# [66/99] Processing: 122_kit.png... ✅ Done.
# [67/99] Processing: 123_kit.png... ✅ Done.
# [68/99] Processing: 123_kit.png... ✅ Done.
# [69/99] Processing: 123_kit.png... ✅ Done.
# [70/99] Processing: 123_kit2.png... ✅ Done.
# [71/99] Processing: 123_kit2.png... ✅ Done.
# [72/99] Processing: 123_kit2.png... ✅ Done.
# [73/99] Processing: 124_kit.png... ✅ Done.
# [74/99] Processing: 124_kit.png... ✅ Done.
# [75/99] Processing: 124_kit.png... ✅ Done.
# [76/99] Processing: 126_kit.png... ✅ Done.
# [77/99] Processing: 126_kit.png... ✅ Done.
# [78/99] Processing: 126_kit.png... ✅ Done.
# [79/99] Processing: 127_kit1.png... ✅ Done.
# [80/99] Processing: 127_kit1.png... ✅ Done.
# [81/99] Processing: 127_kit1.png... ✅ Done.
# [82/99] Processing: 127_kit2.png... ✅ Done.
# [83/99] Processing: 127_kit2.png... ✅ Done.
# [84/99] Processing: 127_kit2.png... ✅ Done.
# [85/99] Processing: 128_kit.png... ✅ Done.
# [86/99] Processing: 128_kit.png... ✅ Done.
# [87/99] Processing: 128_kit.png... ✅ Done.
# [88/99] Processing: 129_kit.png... ✅ Done.
# [89/99] Processing: 129_kit.png... ✅ Done.
# [90/99] Processing: 129_kit.png... ✅ Done.
# [91/99] Processing: 130_kit.png... ✅ Done.
# [92/99] Processing: 130_kit.png... ✅ Done.
# [93/99] Processing: 130_kit.png... ✅ Done.
# [94/99] Processing: 132_kit.png... ✅ Done.
# [95/99] Processing: 132_kit.png... ✅ Done.
# [96/99] Processing: 132_kit.png... ✅ Done.
# [97/99] Processing: 133_kit.png... ✅ Done.
# [98/99] Processing: 133_kit.png... ✅ Done.
# [99/99] Processing: 133_kit.png... ✅ Done.
# Getting descriptions for  on bathroom
# Get images and captions
# Selected folder: ../../drawings/
# 90
# (90, 14)
# 🚀 Starting batch. Data will be saved to: ../../drawings/gem_2-5_descriptions_bathroom.csv
# [1/90] Processing: 101_bat.png... ✅ Done.
# [2/90] Processing: 101_bat.png... ✅ Done.
# [3/90] Processing: 101_bat.png... ✅ Done.
# [4/90] Processing: 102_bat.png... ✅ Done.
# [5/90] Processing: 102_bat.png... ✅ Done.
# [6/90] Processing: 102_bat.png... ✅ Done.
# [7/90] Processing: 103_bat.png... ✅ Done.
# [8/90] Processing: 103_bat.png... ✅ Done.
# [9/90] Processing: 103_bat.png... ✅ Done.
# [10/90] Processing: 104_bat.png... ✅ Done.
# [11/90] Processing: 104_bat.png... ✅ Done.
# [12/90] Processing: 104_bat.png... ✅ Done.
# [13/90] Processing: 105_bat.png... ✅ Done.
# [14/90] Processing: 105_bat.png... ✅ Done.
# [15/90] Processing: 105_bat.png... ✅ Done.
# [16/90] Processing: 106_bat.png... ✅ Done.
# [17/90] Processing: 106_bat.png... ✅ Done.
# [18/90] Processing: 106_bat.png... ✅ Done.
# [19/90] Processing: 107_bat.png... ✅ Done.
# [20/90] Processing: 107_bat.png... ✅ Done.
# [21/90] Processing: 107_bat.png... ✅ Done.
# [22/90] Processing: 108_bat.png... ✅ Done.
# [23/90] Processing: 108_bat.png... ✅ Done.
# [24/90] Processing: 108_bat.png... ✅ Done.
# [25/90] Processing: 109_bat.png... ✅ Done.
# [26/90] Processing: 109_bat.png... ✅ Done.
# [27/90] Processing: 109_bat.png... ✅ Done.
# [28/90] Processing: 110_bat.png... ✅ Done.
# [29/90] Processing: 110_bat.png... ✅ Done.
# [30/90] Processing: 110_bat.png... ✅ Done.
# [31/90] Processing: 111_bat.png... ✅ Done.
# [32/90] Processing: 111_bat.png... ✅ Done.
# [33/90] Processing: 111_bat.png... ✅ Done.
# [34/90] Processing: 112_bat.png... ✅ Done.
# [35/90] Processing: 112_bat.png... ✅ Done.
# [36/90] Processing: 112_bat.png... ✅ Done.
# [37/90] Processing: 113_bat.png... ✅ Done.
# [38/90] Processing: 113_bat.png... ✅ Done.
# [39/90] Processing: 113_bat.png... ✅ Done.
# [40/90] Processing: 114_bat.png... ✅ Done.
# [41/90] Processing: 114_bat.png... ✅ Done.
# [42/90] Processing: 114_bat.png... ✅ Done.
# [43/90] Processing: 115_bat.png... ✅ Done.
# [44/90] Processing: 115_bat.png... ✅ Done.
# [45/90] Processing: 115_bat.png... ✅ Done.
# [46/90] Processing: 116_bat.png... ✅ Done.
# [47/90] Processing: 116_bat.png... ✅ Done.
# [48/90] Processing: 116_bat.png... ✅ Done.
# [49/90] Processing: 117_bat.png... ✅ Done.
# [50/90] Processing: 117_bat.png... ✅ Done.
# [51/90] Processing: 117_bat.png... ✅ Done.
# [52/90] Processing: 119_bat.png... ✅ Done.
# [53/90] Processing: 119_bat.png... ✅ Done.
# [54/90] Processing: 119_bat.png... ✅ Done.
# [55/90] Processing: 120_bat.png... ✅ Done.
# [56/90] Processing: 120_bat.png... ✅ Done.
# [57/90] Processing: 120_bat.png... ✅ Done.
# [58/90] Processing: 121_bat.png... ✅ Done.
# [59/90] Processing: 121_bat.png... ✅ Done.
# [60/90] Processing: 121_bat.png... ✅ Done.
# [61/90] Processing: 122_bat.png... ✅ Done.
# [62/90] Processing: 122_bat.png... ✅ Done.
# [63/90] Processing: 122_bat.png... ✅ Done.
# [64/90] Processing: 123_bat.png... ✅ Done.
# [65/90] Processing: 123_bat.png... ✅ Done.
# [66/90] Processing: 123_bat.png... ✅ Done.
# [67/90] Processing: 124_bat.png... ✅ Done.
# [68/90] Processing: 124_bat.png... ✅ Done.
# [69/90] Processing: 124_bat.png... ✅ Done.
# [70/90] Processing: 126_bat.png... ✅ Done.
# [71/90] Processing: 126_bat.png... ✅ Done.
# [72/90] Processing: 126_bat.png... ✅ Done.
# [73/90] Processing: 127_bat.png... ✅ Done.
# [74/90] Processing: 127_bat.png... ✅ Done.
# [75/90] Processing: 127_bat.png... ✅ Done.
# [76/90] Processing: 128_bat.png... ✅ Done.
# [77/90] Processing: 128_bat.png... ✅ Done.
# [78/90] Processing: 128_bat.png... ✅ Done.
# [79/90] Processing: 129_bat.png... ✅ Done.
# [80/90] Processing: 129_bat.png... ✅ Done.
# [81/90] Processing: 129_bat.png... ✅ Done.
# [82/90] Processing: 130_bat.png... ✅ Done.
# [83/90] Processing: 130_bat.png... ✅ Done.
# [84/90] Processing: 130_bat.png... ✅ Done.
# [85/90] Processing: 132_bat.png... ✅ Done.
# [86/90] Processing: 132_bat.png... ✅ Done.
# [87/90] Processing: 132_bat.png... ✅ Done.
# [88/90] Processing: 133_bat.png... ✅ Done.
# [89/90] Processing: 133_bat.png... ✅ Done.
# [90/90] Processing: 133_bat.png... ✅ Done.
# Getting descriptions for _control on bathroom
# Get images and captions
# Selected folder: ../../drawings/
# 90
# (90, 17)
# 🚀 Starting batch. Data will be saved to: ../../drawings/gem_2-5_descriptions_bathroom_control.csv
# [1/90] Processing: 101_bat_copy.png... ✅ Done.
# [2/90] Processing: 101_bat_copy.png... ✅ Done.
# [3/90] Processing: 101_bat_copy.png... ✅ Done.
# [4/90] Processing: 102_bat_copy.png... ✅ Done.
# [5/90] Processing: 102_bat_copy.png... ✅ Done.
# [6/90] Processing: 102_bat_copy.png... ✅ Done.
# [7/90] Processing: 103_bat_copy.png... ✅ Done.
# [8/90] Processing: 103_bat_copy.png... ✅ Done.
# [9/90] Processing: 103_bat_copy.png... ✅ Done.
# [10/90] Processing: 104_bat_copy.png... ✅ Done.
# [11/90] Processing: 104_bat_copy.png... ✅ Done.
# [12/90] Processing: 104_bat_copy.png... ✅ Done.
# [13/90] Processing: 105_bat_copy.png... ✅ Done.
# [14/90] Processing: 105_bat_copy.png... ✅ Done.
# [15/90] Processing: 105_bat_copy.png... ✅ Done.
# [16/90] Processing: 106_bat_copy.png... ✅ Done.
# [17/90] Processing: 106_bat_copy.png... ✅ Done.
# [18/90] Processing: 106_bat_copy.png... ✅ Done.
# [19/90] Processing: 107_bat_copy.png... ✅ Done.
# [20/90] Processing: 107_bat_copy.png... ✅ Done.
# [21/90] Processing: 107_bat_copy.png... ✅ Done.
# [22/90] Processing: 108_bat_copy.png... ✅ Done.
# [23/90] Processing: 108_bat_copy.png... ✅ Done.
# [24/90] Processing: 108_bat_copy.png... ✅ Done.
# [25/90] Processing: 109_bat_copy.png... ✅ Done.
# [26/90] Processing: 109_bat_copy.png... ✅ Done.
# [27/90] Processing: 109_bat_copy.png... ✅ Done.
# [28/90] Processing: 110_bat_copy.png... ✅ Done.
# [29/90] Processing: 110_bat_copy.png... ✅ Done.
# [30/90] Processing: 110_bat_copy.png... ✅ Done.
# [31/90] Processing: 111_bat_copy.png... ✅ Done.
# [32/90] Processing: 111_bat_copy.png... ✅ Done.
# [33/90] Processing: 111_bat_copy.png... ✅ Done.
# [34/90] Processing: 112_bat_copy.png... ✅ Done.
# [35/90] Processing: 112_bat_copy.png... ✅ Done.
# [36/90] Processing: 112_bat_copy.png... ✅ Done.
# [37/90] Processing: 113_bat_copy.png... ✅ Done.
# [38/90] Processing: 113_bat_copy.png... ✅ Done.
# [39/90] Processing: 113_bat_copy.png... ✅ Done.
# [40/90] Processing: 114_bat_copy.png... ✅ Done.
# [41/90] Processing: 114_bat_copy.png... ✅ Done.
# [42/90] Processing: 114_bat_copy.png... ✅ Done.
# [43/90] Processing: 115_bat_copy.png... ✅ Done.
# [44/90] Processing: 115_bat_copy.png... ✅ Done.
# [45/90] Processing: 115_bat_copy.png... ✅ Done.
# [46/90] Processing: 116_bat_copy.png... ✅ Done.
# [47/90] Processing: 116_bat_copy.png... ✅ Done.
# [48/90] Processing: 116_bat_copy.png... ✅ Done.
# [49/90] Processing: 117_bat_copy.png... ✅ Done.
# [50/90] Processing: 117_bat_copy.png... ✅ Done.
# [51/90] Processing: 117_bat_copy.png... ✅ Done.
# [52/90] Processing: 119_bat_copy.png... ✅ Done.
# [53/90] Processing: 119_bat_copy.png... ✅ Done.
# [54/90] Processing: 119_bat_copy.png... ✅ Done.
# [55/90] Processing: 120_bat_copy.png... ✅ Done.
# [56/90] Processing: 120_bat_copy.png... ✅ Done.
# [57/90] Processing: 120_bat_copy.png... ✅ Done.
# [58/90] Processing: 121_bat_copy.png... ✅ Done.
# [59/90] Processing: 121_bat_copy.png... ✅ Done.
# [60/90] Processing: 121_bat_copy.png... ✅ Done.
# [61/90] Processing: 122_bat_copy.png... ✅ Done.
# [62/90] Processing: 122_bat_copy.png... ✅ Done.
# [63/90] Processing: 122_bat_copy.png... ✅ Done.
# [64/90] Processing: 123_bat_copy.png... ✅ Done.
# [65/90] Processing: 123_bat_copy.png... ✅ Done.
# [66/90] Processing: 123_bat_copy.png... ✅ Done.
# [67/90] Processing: 124_bat_copy.png... ✅ Done.
# [68/90] Processing: 124_bat_copy.png... ✅ Done.
# [69/90] Processing: 124_bat_copy.png... ✅ Done.
# [70/90] Processing: 126_bat_copy.png... ✅ Done.
# [71/90] Processing: 126_bat_copy.png... ✅ Done.
# [72/90] Processing: 126_bat_copy.png... ✅ Done.
# [73/90] Processing: 127_bat_copy.png... ✅ Done.
# [74/90] Processing: 127_bat_copy.png... ✅ Done.
# [75/90] Processing: 127_bat_copy.png... ✅ Done.
# [76/90] Processing: 128_bat_copy.png... ✅ Done.
# [77/90] Processing: 128_bat_copy.png... ✅ Done.
# [78/90] Processing: 128_bat_copy.png... ✅ Done.
# [79/90] Processing: 129_bat_copy.png... ✅ Done.
# [80/90] Processing: 129_bat_copy.png... ✅ Done.
# [81/90] Processing: 129_bat_copy.png... ✅ Done.
# [82/90] Processing: 130_bat_copy.png... ✅ Done.
# [83/90] Processing: 130_bat_copy.png... ✅ Done.
# [84/90] Processing: 130_bat_copy.png... ✅ Done.
# [85/90] Processing: 132_bat_copy.png... ✅ Done.
# [86/90] Processing: 132_bat_copy.png... ✅ Done.
# [87/90] Processing: 132_bat_copy.png... ✅ Done.
# [88/90] Processing: 133_bat_copy.png... ✅ Done.
# [89/90] Processing: 133_bat_copy.png... ✅ Done.
# [90/90] Processing: 133_bat_copy.png... ✅ Done.
# Getting descriptions for _photos on bathroom
# Get images and captions
# Selected folder: ../../photos/
# 132
# (0, 0)
# 🚀 Starting batch. Data will be saved to: ../../photos/gem_2-5_descriptions_bathroom_photos.csv
# [1/132] Processing: 101_bat1.png... ✅ Done.
# [2/132] Processing: 101_bat1.png... ✅ Done.
# [3/132] Processing: 101_bat1.png... ✅ Done.
# [4/132] Processing: 101_bat2.png... ✅ Done.
# [5/132] Processing: 101_bat2.png... ✅ Done.
# [6/132] Processing: 101_bat2.png... ✅ Done.
# [7/132] Processing: 102_bat.png... ✅ Done.
# [8/132] Processing: 102_bat.png... ✅ Done.
# [9/132] Processing: 102_bat.png... ✅ Done.
# [10/132] Processing: 103_bat.png... ✅ Done.
# [11/132] Processing: 103_bat.png... ✅ Done.
# [12/132] Processing: 103_bat.png... ✅ Done.
# [13/132] Processing: 104_bat1.png... ✅ Done.
# [14/132] Processing: 104_bat1.png... ✅ Done.
# [15/132] Processing: 104_bat1.png... ✅ Done.
# [16/132] Processing: 104_bat2.png... ✅ Done.
# [17/132] Processing: 104_bat2.png... ✅ Done.
# [18/132] Processing: 104_bat2.png... ✅ Done.
# [19/132] Processing: 105_bat.png... ✅ Done.
# [20/132] Processing: 105_bat.png... ✅ Done.
# [21/132] Processing: 105_bat.png... ✅ Done.
# [22/132] Processing: 105_bat2.png... ✅ Done.
# [23/132] Processing: 105_bat2.png... ✅ Done.
# [24/132] Processing: 105_bat2.png... ✅ Done.
# [25/132] Processing: 106_bat.png... ✅ Done.
# [26/132] Processing: 106_bat.png... ✅ Done.
# [27/132] Processing: 106_bat.png... ✅ Done.
# [28/132] Processing: 107_bat.png... ✅ Done.
# [29/132] Processing: 107_bat.png... ✅ Done.
# [30/132] Processing: 107_bat.png... ✅ Done.
# [31/132] Processing: 107_bat2.png... ✅ Done.
# [32/132] Processing: 107_bat2.png... ✅ Done.
# [33/132] Processing: 107_bat2.png... ✅ Done.
# [34/132] Processing: 108_bat.png... ✅ Done.
# [35/132] Processing: 108_bat.png... ✅ Done.
# [36/132] Processing: 108_bat.png... ✅ Done.
# [37/132] Processing: 109_bat.png... ✅ Done.
# [38/132] Processing: 109_bat.png... ✅ Done.
# [39/132] Processing: 109_bat.png... ✅ Done.
# [40/132] Processing: 109_bat2.png... ✅ Done.
# [41/132] Processing: 109_bat2.png... ✅ Done.
# [42/132] Processing: 109_bat2.png... ✅ Done.
# [43/132] Processing: 110_bat.png... ✅ Done.
# [44/132] Processing: 110_bat.png... ✅ Done.
# [45/132] Processing: 110_bat.png... ✅ Done.
# [46/132] Processing: 111_bat.png... ✅ Done.
# [47/132] Processing: 111_bat.png... ✅ Done.
# [48/132] Processing: 111_bat.png... ✅ Done.
# [49/132] Processing: 112_bat.png... ✅ Done.
# [50/132] Processing: 112_bat.png... ✅ Done.
# [51/132] Processing: 112_bat.png... ✅ Done.
# [52/132] Processing: 112_bat2.png... ✅ Done.
# [53/132] Processing: 112_bat2.png... ✅ Done.
# [54/132] Processing: 112_bat2.png... ✅ Done.
# [55/132] Processing: 113_bat.png... ✅ Done.
# [56/132] Processing: 113_bat.png... ✅ Done.
# [57/132] Processing: 113_bat.png... ✅ Done.
# [58/132] Processing: 114_bat.png... ✅ Done.
# [59/132] Processing: 114_bat.png... ✅ Done.
# [60/132] Processing: 114_bat.png... ✅ Done.
# [61/132] Processing: 115_bat1.png... ✅ Done.
# [62/132] Processing: 115_bat1.png... ✅ Done.
# [63/132] Processing: 115_bat1.png... ✅ Done.
# [64/132] Processing: 115_bat2.png... ✅ Done.
# [65/132] Processing: 115_bat2.png... ✅ Done.
# [66/132] Processing: 115_bat2.png... ✅ Done.
# [67/132] Processing: 116_bat1.png... ✅ Done.
# [68/132] Processing: 116_bat1.png... ✅ Done.
# [69/132] Processing: 116_bat1.png... ✅ Done.
# [70/132] Processing: 116_bat2.png... ✅ Done.
# [71/132] Processing: 116_bat2.png... ✅ Done.
# [72/132] Processing: 116_bat2.png... ✅ Done.
# [73/132] Processing: 117_bat1.png... ✅ Done.
# [74/132] Processing: 117_bat1.png... ✅ Done.
# [75/132] Processing: 117_bat1.png... ✅ Done.
# [76/132] Processing: 117_bat2.png... ✅ Done.
# [77/132] Processing: 117_bat2.png... ⚠️ Attempt 1 failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The service is currently unavailable.', 'status': 'UNAVAILABLE'}}. Retrying in 10s...
# ✅ Done.
# [78/132] Processing: 117_bat2.png... ✅ Done.
# [79/132] Processing: 119_bat.png... ✅ Done.
# [80/132] Processing: 119_bat.png... ✅ Done.
# [81/132] Processing: 119_bat.png... ✅ Done.
# [82/132] Processing: 120_bat1.png... ✅ Done.
# [83/132] Processing: 120_bat1.png... ✅ Done.
# [84/132] Processing: 120_bat1.png... ✅ Done.
# [85/132] Processing: 120_bat2.png... ✅ Done.
# [86/132] Processing: 120_bat2.png... ✅ Done.
# [87/132] Processing: 120_bat2.png... ✅ Done.
# [88/132] Processing: 121_bat1.png... ✅ Done.
# [89/132] Processing: 121_bat1.png... ✅ Done.
# [90/132] Processing: 121_bat1.png... ✅ Done.
# [91/132] Processing: 121_bat2.png... ✅ Done.
# [92/132] Processing: 121_bat2.png... ✅ Done.
# [93/132] Processing: 121_bat2.png... ✅ Done.
# [94/132] Processing: 122_bat1.png... ✅ Done.
# [95/132] Processing: 122_bat1.png... ✅ Done.
# [96/132] Processing: 122_bat1.png... ✅ Done.
# [97/132] Processing: 122_bat2.png... ✅ Done.
# [98/132] Processing: 122_bat2.png... ✅ Done.
# [99/132] Processing: 122_bat2.png... ✅ Done.
# [100/132] Processing: 123_bat1.png... ✅ Done.
# [101/132] Processing: 123_bat1.png... ✅ Done.
# [102/132] Processing: 123_bat1.png... ✅ Done.
# [103/132] Processing: 123_bat2.png... ✅ Done.
# [104/132] Processing: 123_bat2.png... ✅ Done.
# [105/132] Processing: 123_bat2.png... ✅ Done.
# [106/132] Processing: 124_bat.png... ✅ Done.
# [107/132] Processing: 124_bat.png... ✅ Done.
# [108/132] Processing: 124_bat.png... ✅ Done.
# [109/132] Processing: 126_bat.png... ✅ Done.
# [110/132] Processing: 126_bat.png... ✅ Done.
# [111/132] Processing: 126_bat.png... ✅ Done.
# [112/132] Processing: 127_bat.png... ✅ Done.
# [113/132] Processing: 127_bat.png... ✅ Done.
# [114/132] Processing: 127_bat.png... ✅ Done.
# [115/132] Processing: 128_bat1.png... ✅ Done.
# [116/132] Processing: 128_bat1.png... ✅ Done.
# [117/132] Processing: 128_bat1.png... ✅ Done.
# [118/132] Processing: 128_bat2.png... ✅ Done.
# [119/132] Processing: 128_bat2.png... ✅ Done.
# [120/132] Processing: 128_bat2.png... ✅ Done.
# [121/132] Processing: 129_bat.png... ✅ Done.
# [122/132] Processing: 129_bat.png... ✅ Done.
# [123/132] Processing: 129_bat.png... ✅ Done.
# [124/132] Processing: 130_bat.png... ✅ Done.
# [125/132] Processing: 130_bat.png... ✅ Done.
# [126/132] Processing: 130_bat.png... ✅ Done.
# [127/132] Processing: 132_bat.png... ✅ Done.
# [128/132] Processing: 132_bat.png... ✅ Done.
# [129/132] Processing: 132_bat.png... ✅ Done.
# [130/132] Processing: 133_bat.png... ✅ Done.
# [131/132] Processing: 133_bat.png... ✅ Done.
# [132/132] Processing: 133_bat.png... ✅ Done.

# %% [markdown]
# Get MPNet Model

# %%
from huggingface_hub import snapshot_download

# This downloads the files directly without checking for chat templates
model_path = snapshot_download(
    repo_id="sentence-transformers/all-mpnet-base-v2",
    revision="main",
    ignore_patterns=["additional_chat_templates"] 
)

print(f"✅ Model files are safely located at: {model_path}")

model = SentenceTransformer(model_path)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 28 files:   0%|          | 0/28 [00:00<?, ?it/s]
# ✅ Model files are safely located at: C:\Users\JLU-SU\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2\snapshots\e8c3b32edf5434bc2275fc9bab85f82640a19130
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: C:\Users\JLU-SU\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2\snapshots\e8c3b32edf5434bc2275fc9bab85f82640a19130
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# Similarities of MPNet embeddings

# %%
def process_similarities_MPNet(csv_name, cate):

    if "photos" in csv_name:
        csv_path = os.path.join("../../photos", csv_name)
    else:
        csv_path = os.path.join("../../drawings", csv_name)
        
    if not os.path.exists(csv_path):
        print(f"❌ CSV file not found: {csv_path}")
        return
    
    df = pd.read_csv(csv_path)

    # If the expected columns are missing, create them by concatenating all columns into a single description
    if 'detailed_description' not in df.columns or 'filename' not in df.columns:
        df['detailed_description'] = df.apply(lambda row: ', '.join([str(row[col]) for col in df.columns]), axis=1)
        df['filename'] = range(len(df))
        df = df[['filename', 'detailed_description']] 

    descriptions = df['detailed_description'].fillna("").tolist()
    filenames = df['filename'].tolist()

    print(f"🔍 Encoding {len(descriptions)} descriptions...")
    
    # 1. Generate Embeddings
    embeddings = model.encode(descriptions, convert_to_tensor=True)
    
    # 2. Calculate Dissimilarity
    spearman_corr, _ = spearmanr(embeddings, axis=1)
    spearman_dissimilarity = 1 - spearman_corr
    
    # 3. Create DataFrame
    sim_df = pd.DataFrame(spearman_dissimilarity, index=filenames, columns=filenames)
    
    # 4. Save and Plot
    base_name = os.path.splitext(csv_name)[0]
    if "photos" in csv_name:
        path_out = os.path.join("../../photos", f"{base_name}_MPNet_spearman.csv")
    else:
        path_out = os.path.join("../../drawings", f"{base_name}_MPNet_spearman.csv")
    sim_df.to_csv(path_out) 

    print(f"Spearman dissimilarity matrix saved to: {path_out} ✅")
    
    #plt.figure(figsize=(10, 8))
    #sns.heatmap(sim_df, cmap='viridis', vmin=0.3, vmax=1.0)
    #plt.title(f"Similarity Matrix: {csv_name}")
    #plt.show()
    
    return sim_df

# Execute for gemini-2.5 descriptions
kit_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_bathroom.csv", 'bathroom')
bat_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_kitchen.csv", 'kitchen')

kit_ctr_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_bathroom_control.csv", 'bathroom')
bat_ctr_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_kitchen_control.csv", 'kitchen')

kit_photo_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_bathroom_photos.csv", 'bathroom')
bat_photo_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_kitchen_photos.csv", 'kitchen')
# Out:
# 🔍 Encoding 90 descriptions...
# Spearman dissimilarity matrix saved to: ../../drawings\gem_2-5_descriptions_bathroom_MPNet_spearman.csv ✅
# 🔍 Encoding 90 descriptions...
# Spearman dissimilarity matrix saved to: ../../drawings\gem_2-5_descriptions_kitchen_MPNet_spearman.csv ✅
# 🔍 Encoding 90 descriptions...
# Spearman dissimilarity matrix saved to: ../../drawings\gem_2-5_descriptions_bathroom_control_MPNet_spearman.csv ✅
# 🔍 Encoding 90 descriptions...
# Spearman dissimilarity matrix saved to: ../../drawings\gem_2-5_descriptions_kitchen_control_MPNet_spearman.csv ✅
# 🔍 Encoding 132 descriptions...
# Spearman dissimilarity matrix saved to: ../../photos\gem_2-5_descriptions_bathroom_photos_MPNet_spearman.csv ✅
# 🔍 Encoding 99 descriptions...
# Spearman dissimilarity matrix saved to: ../../photos\gem_2-5_descriptions_kitchen_photos_MPNet_spearman.csv ✅

# %%
bat_ctr_matrix_desc_mpnet = process_similarities_MPNet("gem_2-5_descriptions_kitchen_control.csv", 'kitchen')
# Out:
# 🔍 Encoding 35 descriptions...
# Cosine dissimilarity matrix saved to: ../../image_similarities/drawings_draw3D/used_drawings_exp1/control\kitchen\gem_2-5_descriptions_kitchen_control_MPNet_cosine.csv ✅
